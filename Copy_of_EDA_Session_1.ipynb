# %% [markdown]
# <a href="https://colab.research.google.com/github/21A91A6136/EDA-Series/blob/main/Copy_of_EDA_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/content/EasyVisa.csv"
# file_path = "E:\\Archive\\EasyVisa.csv"

# %%
pd.read_csv(file_path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from os import name
l1=["ram","reddy","rowdy"]
l2 = [10,11,21]
cols = ["name","age"]
names = pd.DataFrame(zip(l1,l2),columns=cols)
names
# Out:
#     name  age
# 0    ram   10
# 1  reddy   11
# 2  rowdy   21

# %% [markdown]
# #names.to_csv("Name.csv") -- to save in local host
# #names.to_csv("Name.csv",index = False) -- Remove index values

# %%
names['city'] = ["Hyd","chennai","Bnglr"]
names
# Out:
#     name  age     city
# 0    ram   10      Hyd
# 1  reddy   11  chennai
# 2  rowdy   21    Bnglr

# %%
names.drop('city',axis=1,inplace=True)

# %%
names
# Out:
#     name  age
# 0    ram   10
# 1  reddy   11
# 2  rowdy   21

# %%
dict1 = {'names':["ram","reddy","rowdy"],
         'ages' :[10,11,21]}
dict1
# Out:
# {'names': ['ram', 'reddy', 'rowdy'], 'ages': [10, 11, 21]}

# %%
pd.DataFrame(dict1)
# keys automatically becomes columns, values as rows
# Out:
#    names  ages
# 0    ram    10
# 1  reddy    11
# 2  rowdy    21

# %%
pd.DataFrame(dict1,index=["A","B","C"])
# index=["A","B","C"] we can change
# we cannot change columns = ["A","B"]
# Out:
#    names  ages
# A    ram    10
# B  reddy    11
# C  rowdy    21
